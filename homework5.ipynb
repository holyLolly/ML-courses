# %% [markdown]
# # Домашняя работа 5. Линейная регрессия. (33 балла)
#
# > Линейная регрессия - это не повод для затяжной депрессии.
#
# 1. Скачайте этот ноутбук к себе.
# 2. Заполните пропущенные ячейки, отвечая на заданные вопросы. Там должен быть код! (если не сказано обратное)
# 3. Сохраните результат в своём гитхаб репозитории.
# 4. Пришлите на почту ml-teachers ссылку на этот файл в вашем репозитории.
# 5. В теме письма указать `ML Homework #5: Name Surname`. Если тема будет неправильная, то задание не будет проверено.
#
# **Дедлайн**: 27.11.2017 01:00 OMSK
#
#     После дедлайна можно сдать, но вы получите штраф по баллам в рейтинге.
#
# **Рассылка решений**: 30.11.2017 17:00 OMSK
#
#     После рассылки задания совсем не имеют веса.
#
# ### Полезная литература
#
# - [Первый конспект лекции про линейную регрессию из курса ФШЭ](https://github.com/esokolov/ml-course-hse/blob/master/2016-fall/lecture-notes/lecture02-linregr.pdf)
# - [Второй конспект лекции про линейную регрессию из курса ФШЭ](https://github.com/esokolov/ml-course-hse/blob/master/2016-fall/lecture-notes/lecture03-linregr.pdf)
# - [Теория из курса ODS](https://github.com/Yorko/mlcourse_open/blob/master/jupyter_notebooks/topic04_linear_models/topic4_linear_models_part1_mse_likelihood_bias_variance.ipynb)
# - [Материалы из курса от МФТИ](https://www.coursera.org/specializations/machine-learning-data-analysis)
# - [Статья про лин.рег. от ODS на habrahabr](https://habrahabr.ru/company/ods/blog/323890/)

# %% [markdown]
# ## Данные
#
# Возьмем датасет о стоимости домов: https://www.kaggle.com/c/house-prices-advanced-regression-techniques/data. Там же читайте описание данных.
#
# Целевой переменной будет `SalePrice`. То есть мы будем предсказывать стоимость жилья на основе его характеристик. Это задание будет не то чтобы про линейную регрессию, но про попытку построить модель для предсказания цен на дом. В принципе я бы мог еще добавить заданий на более тщательный отбор признаков, логарифмирование признаков у которых сильное смещение "скоса"(skew). Можно было бы анализировать и выпрямлять распределение целевой переменной. Можно было бы генерировать новые признаки из существующих, строить ансаибли моделей. Но тут мы ограничимся пока что.......

# %%
import pandas as pd
import numpy as np
from scipy import stats
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('house_prices.csv.gz', index_col='Id')
df.head()
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
# 4           70       RL         60.0     9550   Pave   NaN      IR1
# 5           60       RL         84.0    14260   Pave   NaN      IR1
#
#    LandContour Utilities LotConfig    ...     PoolArea PoolQC Fence  \
# Id                                    ...
# 1          Lvl    AllPub    Inside    ...            0    NaN   NaN
# 2          Lvl    AllPub       FR2    ...            0    NaN   NaN
# 3          Lvl    AllPub    Inside    ...            0    NaN   NaN
# 4          Lvl    AllPub    Corner    ...            0    NaN   NaN
# 5          Lvl    AllPub       FR2    ...            0    NaN   NaN
#
#    MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 1          NaN       0      2    2008        WD         Normal     208500
# 2          NaN       0      5    2007        WD         Normal     181500
# 3          NaN       0      9    2008        WD         Normal     223500
# 4          NaN       0      2    2006        WD        Abnorml     140000
# 5          NaN       0     12    2008        WD         Normal     250000
#
# [5 rows x 80 columns]

# %%
assert df.shape == (1460, 80)

# %%
df.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street', 'Alley',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
#        'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond',
#        'PavedDrive', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
#        'ScreenPorch', 'PoolArea', 'PoolQC', 'Fence', 'MiscFeature', 'MiscVal',
#        'MoSold', 'YrSold', 'SaleType', 'SaleCondition', 'SalePrice'],
#       dtype='object')

# %% [markdown]
# ## 1.0 Анализ целевого признака (3 балла)
#
# Удостоверимся, что раcпределение целевого признака "хорошее", без странных выбросов. В идеале мы хотим видеть нормальное распределени или достаточно похожее на него, без очень длинных "хвостов" выбросов.
#
# _Почему требуется нормальность распределения: ищите объяснения линейной регресси через алгоритмы максимизации правдоподобия. В итоге, грубо говоря, суть сводится к тому, что с ростом объема выборки, оценка максимального правдоподобия лучше описывает нормальное распределение._
#
# [Коэффициент эксцесса](http://www.machinelearning.ru/wiki/index.php?title=%D0%9A%D0%BE%D1%8D%D1%84%D1%84%D0%B8%D1%86%D0%B8%D0%B5%D0%BD%D1%82_%D1%8D%D0%BA%D1%81%D1%86%D0%B5%D1%81%D1%81%D0%B0) показывает степень остроты пика распределения случайной величины. Для нормального распределения он равен `0`. Если хвосты распределения «тяжелее», а пик более «приплюснутый», чем у нормального распределения, то коэффициент < 0. А если хвосты легкие, то больше 0. В нашем случае должно получиться околов `6.5`.
#
# Задание:
# - Нарисуйте график распределения `SalePrice`, используйте аргумент `fit=scipy.stats.norm`, чтобы нарисовать предполагаемое нормальное распределение. Напечатайте значение коэффициент эксцесса `kurtosis` для этого признака.
# - Нарисуйте график [scipy.stats.probplot](https://docs.scipy.org/doc/scipy-0.14.0/reference/generated/scipy.stats.probplot.html) - он покажет нам реальные квантили выборки и теоретические. По нему можно видеть, на сколько много выьросов и на сколько выборка предсказуема.
# - Что вы можете сказать по поводу выборки основываясь на `probplot`.  [wiki](https://en.wikipedia.org/wiki/Normal_probability_plot)

# %%
sns.distplot(df['SalePrice'], fit = stats.norm)
stats.kurtosis(df['SalePrice'])
# Out:
# 6.509812011089439

# %%
stats.probplot(df['SalePrice'], plot=plt)
# Out:
# ((array([-3.30513952, -3.04793228, -2.90489705, ...,  2.90489705,
#           3.04793228,  3.30513952]),
#   array([ 34900,  35311,  37900, ..., 625000, 745000, 755000], dtype=int64)),
#  (74160.164745194095, 180921.19589041095, 0.9319665641512983))

# %%
От теоретической линии квантилей имеется слишком большое отклонение в конце выборки
Так же имеется некоторое количество значений, много превышающее другие значения выборки - это видно по разрыву графика. Вероятней
    всего - эти значения являются выборсами
# Out:
#   File "<ipython-input-544-73e8fdae68be>", line 1
#     От теоретической линии квантилей имеется слишком большое отклонение в конце выборки
#                    ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## 1.2 Анализ некоторых зависимостей (3 балла)
#
# У нас очень много разных признаков. Любопытно построить разные графики. Позаботьтесь о красоте и наглядности графиков, сделайте так, чтобы они были большие и их можно было прочесть. Даже подписи на графиках должны быть читаемые!!
#
# Задания: Постройте графики, отражающие зависимости этих признаков:
# - дата постройки дома и его стоимости
# - "качество дома и материалов" и его стоимости
# - площадь дома и стоимость
#
# Hints: Вспомните про boxplot, jointplot, lmplot...

# %%
sns.jointplot(x = df['YearBuilt'], y = df['SalePrice'], kind = 'kde', color = 'darkblue', size = 15)

# %%
plt.figure(figsize=(17, 15))
sns.boxplot(x = df['OverallQual'], y = df['SalePrice'], color = 'lime', fliersize = 7)

# %%
sns.lmplot(y = 'LotArea', x = "SalePrice", data = df, size = 15)

# %% [markdown]
# ## 1.2 Heatmap (3 балла)
#
# Судя по предыдущим графикам, есть некоторые линейные зависимости. Но строить по графику на каждый признак из 80 штук немного долго и не наглядно. Постройте красивый график корреляции всех признаков. Используйте цвета `RdYlGn`, так будет нагляднее. Не забудьте применить маску, чтобы убрать дублирующую половину матрицы.

# %%
corr = df.corr()
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
plt.subplots(figsize=(17, 15))
sns.heatmap(corr, cmap = 'RdYlGn', linewidths=.5, mask = mask)

# %% [markdown]
# Большая матрица 38x38 ячеек. И мы видим, там есть сильно коррелируемые объекты с нашей целевой переменной.
#
# - Нарисуйте крупно heatmap этих сильно коррелируемых объектов( больше 0.5 по абсолютному значению) и сделайте так, чтобы в каждой ячейке было значение корреляции.
# - Выведите список этих сильно коррелируемых признаков.
#
# Запомним эти признаки!

# %%
for i in corr.index:
    if corr[i]['SalePrice'] < 0.5:
        corr = corr.drop(i)
        corr = corr.drop(i, axis = 1)
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
sns.heatmap(corr, cmap = 'RdYlGn', linewidths=.5, mask = mask, annot = True)

# %% [markdown]
# ## 1.3 Пропущеные данные (3 балла)

# %% [markdown]
# Задание:
#  - Посчитайте общее количество пропущенных данных по каждому признаку
#  - посчитайте долю пропущенных данных выборки
#  - удалите из выборки признаки, доля пропущенных которых больще 10%
#  - пропущенные категориальные заполните словом 'unknown' (у них dtype object)
#  - пропущенные числовые заполните средним (у них dtype float)
#
# Hinst: https://stackoverflow.com/a/38134049/3205200

# %%
df.fillna(value = -1, inplace = True)
skipNumber = pd.Series(0, index = df.columns)
i = 0
for i in df.columns:
    skipNumber[i] = df[df[i] == -1].shape[0]
skipNumberPercent = skipNumber / df.shape[0]
df.drop(skipNumberPercent[skipNumberPercent > 0.1].index, axis = 1, inplace = True)
i = 0
for i in df.columns:
    if df[i].dtype == 'object':
        df[i][df[i] == -1] = 'unknown'
    if df[i].dtype == 'float64':
        df[i][df[i] == -1] = df[i].mean()

df
# Out:
#       MSSubClass MSZoning  LotArea Street LotShape LandContour Utilities  \
# Id
# 1             60       RL     8450   Pave      Reg         Lvl    AllPub
# 2             20       RL     9600   Pave      Reg         Lvl    AllPub
# 3             60       RL    11250   Pave      IR1         Lvl    AllPub
# 4             70       RL     9550   Pave      IR1         Lvl    AllPub
# 5             60       RL    14260   Pave      IR1         Lvl    AllPub
# 6             50       RL    14115   Pave      IR1         Lvl    AllPub
# 7             20       RL    10084   Pave      Reg         Lvl    AllPub
# 8             60       RL    10382   Pave      IR1         Lvl    AllPub
# 9             50       RM     6120   Pave      Reg         Lvl    AllPub
# 10           190       RL     7420   Pave      Reg         Lvl    AllPub
# 11            20       RL    11200   Pave      Reg         Lvl    AllPub
# 12            60       RL    11924   Pave      IR1         Lvl    AllPub
# 13            20       RL    12968   Pave      IR2         Lvl    AllPub
# 14            20       RL    10652   Pave      IR1         Lvl    AllPub
# 15            20       RL    10920   Pave      IR1         Lvl    AllPub
# 16            45       RM     6120   Pave      Reg         Lvl    AllPub
# 17            20       RL    11241   Pave      IR1         Lvl    AllPub
# 18            90       RL    10791   Pave      Reg         Lvl    AllPub
# 19            20       RL    13695   Pave      Reg         Lvl    AllPub
# 20            20       RL     7560   Pave      Reg         Lvl    AllPub
# 21            60       RL    14215   Pave      IR1         Lvl    AllPub
# 22            45       RM     7449   Pave      Reg         Bnk    AllPub
# 23            20       RL     9742   Pave      Reg         Lvl    AllPub
# 24           120       RM     4224   Pave      Reg         Lvl    AllPub
# 25            20       RL     8246   Pave      IR1         Lvl    AllPub
# 26            20       RL    14230   Pave      Reg         Lvl    AllPub
# 27            20       RL     7200   Pave      Reg         Lvl    AllPub
# 28            20       RL    11478   Pave      Reg         Lvl    AllPub
# 29            20       RL    16321   Pave      IR1         Lvl    AllPub
# 30            30       RM     6324   Pave      IR1         Lvl    AllPub
# ...          ...      ...      ...    ...      ...         ...       ...
# 1431          60       RL    21930   Pave      IR3         Lvl    AllPub
# 1432         120       RL     4928   Pave      IR1         Lvl    AllPub
# 1433          30       RL    10800   Pave      Reg         Lvl    AllPub
# 1434          60       RL    10261   Pave      IR1         Lvl    AllPub
# 1435          20       RL    17400   Pave      Reg         Low    AllPub
# 1436          20       RL     8400   Pave      Reg         Lvl    AllPub
# 1437          20       RL     9000   Pave      Reg         Lvl    AllPub
# 1438          20       RL    12444   Pave      Reg         Lvl    AllPub
# 1439          20       RM     7407   Pave      Reg         Lvl    AllPub
# 1440          60       RL    11584   Pave      Reg         Lvl    AllPub
# 1441          70       RL    11526   Pave      IR1         Bnk    AllPub
# 1442         120       RM     4426   Pave      Reg         Lvl    AllPub
# 1443          60       FV    11003   Pave      Reg         Lvl    AllPub
# 1444          30       RL     8854   Pave      Reg         Lvl    AllPub
# 1445          20       RL     8500   Pave      Reg         Lvl    AllPub
# 1446          85       RL     8400   Pave      Reg         Lvl    AllPub
# 1447          20       RL    26142   Pave      IR1         Lvl    AllPub
# 1448          60       RL    10000   Pave      Reg         Lvl    AllPub
# 1449          50       RL    11767   Pave      Reg         Lvl    AllPub
# 1450         180       RM     1533   Pave      Reg         Lvl    AllPub
# 1451          90       RL     9000   Pave      Reg         Lvl    AllPub
# 1452          20       RL     9262   Pave      Reg         Lvl    AllPub
# 1453         180       RM     3675   Pave      Reg         Lvl    AllPub
# 1454          20       RL    17217   Pave      Reg         Lvl    AllPub
# 1455          20       FV     7500   Pave      Reg         Lvl    AllPub
# 1456          60       RL     7917   Pave      Reg         Lvl    AllPub
# 1457          20       RL    13175   Pave      Reg         Lvl    AllPub
# 1458          70       RL     9042   Pave      Reg         Lvl    AllPub
# 1459          20       RL     9717   Pave      Reg         Lvl    AllPub
# 1460          20       RL     9937   Pave      Reg         Lvl    AllPub
#
#      LotConfig LandSlope Neighborhood    ...    EnclosedPorch 3SsnPorch  \
# Id                                       ...
# 1       Inside       Gtl      CollgCr    ...                0         0
# 2          FR2       Gtl      Veenker    ...                0         0
# 3       Inside       Gtl      CollgCr    ...                0         0
# 4       Corner       Gtl      Crawfor    ...              272         0
# 5          FR2       Gtl      NoRidge    ...                0         0
# 6       Inside       Gtl      Mitchel    ...                0       320
# 7       Inside       Gtl      Somerst    ...                0         0
# 8       Corner       Gtl       NWAmes    ...              228         0
# 9       Inside       Gtl      OldTown    ...              205         0
# 10      Corner       Gtl      BrkSide    ...                0         0
# 11      Inside       Gtl       Sawyer    ...                0         0
# 12      Inside       Gtl      NridgHt    ...                0         0
# 13      Inside       Gtl       Sawyer    ...                0         0
# 14      Inside       Gtl      CollgCr    ...                0         0
# 15      Corner       Gtl        NAmes    ...              176         0
# 16      Corner       Gtl      BrkSide    ...                0         0
# 17     CulDSac       Gtl        NAmes    ...                0         0
# 18      Inside       Gtl       Sawyer    ...                0         0
# 19      Inside       Gtl      SawyerW    ...                0         0
# 20      Inside       Gtl        NAmes    ...                0         0
# 21      Corner       Gtl      NridgHt    ...                0         0
# 22      Inside       Gtl       IDOTRR    ...              205         0
# 23      Inside       Gtl      CollgCr    ...                0         0
# 24      Inside       Gtl      MeadowV    ...                0         0
# 25      Inside       Gtl       Sawyer    ...                0         0
# 26      Corner       Gtl      NridgHt    ...                0         0
# 27      Corner       Gtl        NAmes    ...                0         0
# 28      Inside       Gtl      NridgHt    ...                0         0
# 29     CulDSac       Gtl        NAmes    ...                0         0
# 30      Inside       Gtl      BrkSide    ...               87         0
# ...        ...       ...          ...    ...              ...       ...
# 1431    Inside       Gtl      Gilbert    ...                0         0
# 1432    Inside       Gtl      NPkVill    ...                0         0
# 1433    Inside       Gtl      OldTown    ...                0         0
# 1434    Inside       Gtl      Gilbert    ...                0         0
# 1435    Inside       Mod      Mitchel    ...                0         0
# 1436    Inside       Gtl        NAmes    ...                0         0
# 1437       FR2       Gtl        NAmes    ...                0         0
# 1438       FR2       Gtl      NridgHt    ...                0       304
# 1439    Inside       Gtl      OldTown    ...              158         0
# 1440    Inside       Gtl       NWAmes    ...              216         0
# 1441    Inside       Mod      Crawfor    ...                0         0
# 1442    Inside       Gtl      CollgCr    ...                0         0
# 1443    Inside       Gtl      Somerst    ...                0         0
# 1444    Inside       Gtl      BrkSide    ...                0         0
# 1445       FR2       Gtl      CollgCr    ...                0         0
# 1446    Inside       Gtl       Sawyer    ...              252         0
# 1447   CulDSac       Gtl      Mitchel    ...                0         0
# 1448    Inside       Gtl      CollgCr    ...                0         0
# 1449    Inside       Gtl      Edwards    ...                0         0
# 1450    Inside       Gtl      MeadowV    ...                0         0
# 1451       FR2       Gtl        NAmes    ...                0         0
# 1452    Inside       Gtl      Somerst    ...                0         0
# 1453    Inside       Gtl      Edwards    ...                0         0
# 1454    Inside       Gtl      Mitchel    ...                0         0
# 1455    Inside       Gtl      Somerst    ...                0         0
# 1456    Inside       Gtl      Gilbert    ...                0         0
# 1457    Inside       Gtl       NWAmes    ...                0         0
# 1458    Inside       Gtl      Crawfor    ...                0         0
# 1459    Inside       Gtl        NAmes    ...              112         0
# 1460    Inside       Gtl      Edwards    ...                0         0
#
#      ScreenPorch PoolArea  MiscVal  MoSold  YrSold  SaleType SaleCondition  \
# Id
# 1              0        0        0       2    2008        WD        Normal
# 2              0        0        0       5    2007        WD        Normal
# 3              0        0        0       9    2008        WD        Normal
# 4              0        0        0       2    2006        WD       Abnorml
# 5              0        0        0      12    2008        WD        Normal
# 6              0        0      700      10    2009        WD        Normal
# 7              0        0        0       8    2007        WD        Normal
# 8              0        0      350      11    2009        WD        Normal
# 9              0        0        0       4    2008        WD       Abnorml
# 10             0        0        0       1    2008        WD        Normal
# 11             0        0        0       2    2008        WD        Normal
# 12             0        0        0       7    2006       New       Partial
# 13           176        0        0       9    2008        WD        Normal
# 14             0        0        0       8    2007       New       Partial
# 15             0        0        0       5    2008        WD        Normal
# 16             0        0        0       7    2007        WD        Normal
# 17             0        0      700       3    2010        WD        Normal
# 18             0        0      500      10    2006        WD        Normal
# 19             0        0        0       6    2008        WD        Normal
# 20             0        0        0       5    2009       COD       Abnorml
# 21             0        0        0      11    2006       New       Partial
# 22             0        0        0       6    2007        WD        Normal
# 23             0        0        0       9    2008        WD        Normal
# 24             0        0        0       6    2007        WD        Normal
# 25             0        0        0       5    2010        WD        Normal
# 26             0        0        0       7    2009        WD        Normal
# 27             0        0        0       5    2010        WD        Normal
# 28             0        0        0       5    2010        WD        Normal
# 29             0        0        0      12    2006        WD        Normal
# 30             0        0        0       5    2008        WD        Normal
# ...          ...      ...      ...     ...     ...       ...           ...
# 1431           0        0        0       7    2006        WD        Normal
# 1432           0        0        0      10    2009        WD        Normal
# 1433           0        0        0       8    2007        WD        Normal
# 1434           0        0        0       5    2008        WD        Normal
# 1435           0        0        0       5    2006        WD        Normal
# 1436           0        0        0       7    2008       COD       Abnorml
# 1437           0        0        0       5    2007        WD        Normal
# 1438           0        0        0      11    2008       New       Partial
# 1439           0        0        0       4    2010        WD        Normal
# 1440           0        0        0      11    2007        WD        Normal
# 1441           0        0        0       9    2008        WD        Normal
# 1442           0        0        0       5    2008        WD        Normal
# 1443           0        0        0       4    2009        WD        Normal
# 1444          40        0        0       5    2009        WD        Normal
# 1445           0        0        0      11    2007        WD        Normal
# 1446           0        0        0       5    2007        WD        Normal
# 1447           0        0        0       4    2010        WD        Normal
# 1448           0        0        0      12    2007        WD        Normal
# 1449           0        0        0       5    2007        WD        Normal
# 1450           0        0        0       8    2006        WD       Abnorml
# 1451           0        0        0       9    2009        WD        Normal
# 1452           0        0        0       5    2009       New       Partial
# 1453           0        0        0       5    2006        WD        Normal
# 1454           0        0        0       7    2006        WD       Abnorml
# 1455           0        0        0      10    2009        WD        Normal
# 1456           0        0        0       8    2007        WD        Normal
# 1457           0        0        0       2    2010        WD        Normal
# 1458           0        0     2500       5    2010        WD        Normal
# 1459           0        0        0       4    2010        WD        Normal
# 1460           0        0        0       6    2008        WD        Normal
#
#      SalePrice
# Id
# 1       208500
# 2       181500
# 3       223500
# 4       140000
# 5       250000
# 6       143000
# 7       307000
# 8       200000
# 9       129900
# 10      118000
# 11      129500
# 12      345000
# 13      144000
# 14      279500
# 15      157000
# 16      132000
# 17      149000
# 18       90000
# 19      159000
# 20      139000
# 21      325300
# 22      139400
# 23      230000
# 24      129900
# 25      154000
# 26      256300
# 27      134800
# 28      306000
# 29      207500
# 30       68500
# ...        ...
# 1431    192140
# 1432    143750
# 1433     64500
# 1434    186500
# 1435    160000
# 1436    174000
# 1437    120500
# 1438    394617
# 1439    149700
# 1440    197000
# 1441    191000
# 1442    149300
# 1443    310000
# 1444    121000
# 1445    179600
# 1446    129000
# 1447    157900
# 1448    240000
# 1449    112000
# 1450     92000
# 1451    136000
# 1452    287090
# 1453    145000
# 1454     84500
# 1455    185000
# 1456    175000
# 1457    210000
# 1458    266500
# 1459    142125
# 1460    147500
#
# [1460 rows x 74 columns]

# %% [markdown]
# ## 1.4 Категориальные переменные (1 балл)
#
# На сколько вы помните, линейная регрессия не умеет обрабатывать категориальные признаки, так как ей нужны ЧИСЛА. Но не беда, в pandas есть встроенная функция [get_dummies](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.get_dummies.html).
#
# Задание:
# - сконвертируйте все категориальные признаки(dtype=object) в вектора числовых с помощью get_dummies
# - напечатайте сколько у вас теперь признаков
# - Положите в переменную X все данные из датасета, кроме целевой переменной. Положите в переменную y только целевую переменную.

# %%
df = pd.get_dummies(df)
print(df.shape)

y = df['SalePrice']
X = df.drop(['SalePrice'], axis = 1)
# Out:
# (1460, 281)

# %% [markdown]
# ## 1.5 Переобучение (3 балла)
#
# Обучим обычную модель без регуляризации [sklearn.linear_model.LinearRegression](http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html).
#
# - Выведите все коэффициенты для каждого признака, отсортировав по возрастанию по модулю значения коэффициента. Используйте print и for, иначе jupyter схлопнет вывод numpy массива. Можете округлить коэффициенты до 2 знаков после запятой.
# - Выведите **среднее** ошибки предсказания на 5 фолдах (cv=5) для этой линейной регрессии с помощью функции [sklearn.model_selection.cross_val_score](http://scikit-learn.org/stable/modules/generated/sklearn.model_selection.cross_val_score.html). Укажите `scoring='neg_mean_squared_error'`, чтобы считалась [MSE](http://scikit-learn.org/stable/modules/model_evaluation.html#mean-squared-error)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X, y)
for coef, col in sorted(zip(lr.coef_, df.columns), key=lambda x: np.abs(x[0])):
    print("{} \t {}".format(col, np.round(coef, 2)))
# Out:
# MiscVal 	 0.11
# LotArea 	 0.77
# BsmtUnfSF 	 -1.91
# OpenPorchSF 	 3.46
# EnclosedPorch 	 4.68
# BsmtFinSF2 	 7.14
# WoodDeckSF 	 13.35
# 1stFlrSF 	 16.02
# BsmtFinSF1 	 16.86
# GarageArea 	 18.02
# MasVnrArea 	 18.75
# LowQualFinSF 	 -20.29
# TotalBsmtSF 	 22.09
# GarageYrBlt 	 -27.08
# ScreenPorch 	 28.47
# GrLivArea 	 31.09
# MSSubClass 	 -31.51
# 3SsnPorch 	 32.57
# 2ndFlrSF 	 35.36
# GarageType_unknown 	 37.68
# GarageFinish_RFn 	 -42.23
# Exterior2nd_Wd Sdng 	 -84.57
# PoolArea 	 85.15
# YearRemodAdd 	 97.23
# MasVnrType_BrkCmn 	 127.7
# CentralAir_N 	 146.39
# HeatingQC_TA 	 -146.39
# GarageType_Basment 	 -273.12
# Functional_Min2 	 -277.18
# YearBuilt 	 320.7
# YrSold 	 -403.94
# Exterior2nd_ImStucc 	 424.01
# MoSold 	 -436.53
# Heating_GasW 	 -457.17
# LotShape_Reg 	 -509.16
# Functional_Maj1 	 509.94
# BsmtFinType1_ALQ 	 -527.87
# Exterior2nd_AsphShn 	 -538.04
# BsmtFinType1_Rec 	 541.84
# BsmtHalfBath 	 -618.67
# ExterCond_Ex 	 -644.12
# Exterior1st_CBlock 	 -649.6
# GarageCond_unknown 	 706.89
# BsmtFullBath 	 761.31
# Heating_Wall 	 771.94
# PavedDrive_P 	 787.74
# LotShape_IR3 	 -830.8
# Neighborhood_Sawyer 	 -836.32
# GarageType_2Types 	 841.99
# KitchenQual_TA 	 880.87
# Neighborhood_SawyerW 	 902.85
# HeatingQC_Ex 	 992.72
# LotShape_IR1 	 1000.03
# Neighborhood_Blmngtn 	 1034.8
# TotRmsAbvGrd 	 1097.98
# HalfBath 	 1128.13
# BsmtFinType2_LwQ 	 1158.3
# Exterior1st_CemntBd 	 -1163.54
# BldgType_2fmCon 	 1183.88
# Exterior2nd_Stone 	 1185.7
# Heating_GasA 	 1191.9
# Exterior2nd_Other 	 1246.74
# Exterior1st_VinylSd 	 -1356.34
# BsmtFinType2_ALQ 	 -1475.52
# MSZoning_RL 	 1483.5
# BldgType_TwnhsE 	 1483.79
# PavedDrive_N 	 -1494.63
# Neighborhood_BrDale 	 -1623.08
# BsmtCond_unknown 	 1689.14
# ExterQual_TA 	 1779.19
# BsmtFinType2_Rec 	 1781.12
# Electrical_FuseF 	 -1785.06
# Condition1_Artery 	 1816.86
# LotConfig_FR3 	 1957.42
# Exterior1st_Stucco 	 -2002.49
# Exterior2nd_Brk Cmn 	 -2005.14
# ExterCond_Po 	 -2280.29
# Exterior1st_Wd Sdng 	 2310.43
# Condition1_RRNe 	 2312.87
# BsmtExposure_unknown 	 -2337.0
# LotShape_IR2 	 2397.06
# BsmtFinType1_LwQ 	 -2504.21
# Fireplaces 	 2515.2
# KitchenQual_Ex 	 -2524.24
# Street_Pave 	 -2566.29
# BsmtExposure_Gd 	 -2582.4
# Exterior1st_MetalSd 	 -2601.15
# HeatingQC_Po 	 -2722.52
# GarageFinish_Fin 	 -2781.68
# GarageCond_TA 	 2786.23
# GarageQual_TA 	 2786.23
# GarageType_Detchd 	 2786.23
# GarageFinish_Unf 	 2786.23
# HeatingQC_Fa 	 -2787.47
# SaleType_WD 	 -2788.44
# Neighborhood_Blueste 	 2848.37
# SaleType_New 	 -2913.29
# SaleCondition_Family 	 2917.07
# BsmtQual_Ex 	 -2919.16
# SaleCondition_AdjLand 	 2995.29
# LandSlope_Sev 	 3082.13
# MasVnrType_Stone 	 -3154.47
# Exterior2nd_CmentBd 	 3224.87
# MSZoning_FV 	 3274.32
# SaleCondition_Alloca 	 -3281.62
# BedroomAbvGr 	 -3314.06
# BsmtFinType1_BLQ 	 3322.31
# ExterCond_TA 	 3479.57
# MasVnrType_BrkFace 	 3483.58
# Utilities_NoSeWa 	 3571.3
# FullBath 	 3585.67
# Neighborhood_IDOTRR 	 -3647.4
# HeatingQC_Gd 	 3745.34
# HouseStyle_2Story 	 3818.2
# GarageType_CarPort 	 3854.5
# Condition1_RRAe 	 3864.5
# Condition1_Norm 	 3878.9
# Neighborhood_Timber 	 3995.06
# HouseStyle_2.5Unf 	 -4073.95
# Neighborhood_Veenker 	 -4117.9
# BsmtExposure_Mn 	 -4154.79
# BsmtFinType2_GLQ 	 -4210.47
# GarageCars 	 4263.22
# Exterior1st_AsphShn 	 4372.82
# RoofStyle_Hip 	 -4524.29
# LotConfig_CulDSac 	 -4550.56
# GarageType_Attchd 	 4588.49
# Heating_Floor 	 4620.26
# HouseStyle_SFoyer 	 4719.7
# Exterior2nd_AsbShng 	 4785.24
# MSZoning_RH 	 4808.82
# ExterCond_Fa 	 -4812.17
# SaleCondition_Normal 	 -4813.83
# Foundation_PConc 	 -4901.31
# SaleCondition_Abnorml 	 4971.53
# Neighborhood_OldTown 	 -5067.8
# BldgType_1Fam 	 5137.56
# Exterior2nd_BrkFace 	 -5168.18
# Exterior1st_BrkFace 	 -5168.18
# ExterQual_Ex 	 5184.1
# LandContour_Low 	 5277.78
# SaleType_COD 	 5351.53
# MasVnrType_None 	 5407.95
# BsmtFinType2_unknown 	 -5499.0
# SaleType_ConLD 	 -5563.58
# Exterior1st_Stone 	 5629.41
# OverallCond 	 5702.87
# SaleType_Con 	 5753.04
# KitchenQual_Gd 	 -5753.22
# Electrical_Mix 	 5775.14
# Exterior2nd_VinylSd 	 5778.11
# Exterior2nd_Wd Shng 	 -5864.75
# BsmtQual_Gd 	 -5886.22
# BsmtFinType1_GLQ 	 -5944.13
# ExterCond_Gd 	 5957.39
# Exterior1st_ImStucc 	 6104.69
# Condition1_RRAn 	 -6309.61
# Neighborhood_ClearCr 	 -6559.47
# OverallQual 	 6581.87
# Foundation_BrkTil 	 6634.8
# BldgType_Twnhs 	 -6831.23
# CentralAir_Y 	 7175.69
# Neighborhood_Gilbert 	 -7206.34
# Electrical_FuseA 	 7230.79
# Neighborhood_SWISU 	 -7251.81
# LandContour_Bnk 	 7369.15
# BsmtCond_TA 	 7449.07
# BsmtQual_TA 	 7449.07
# BsmtFinType1_Unf 	 7449.07
# GarageType_BuiltIn 	 7516.85
# Exterior2nd_CBlock 	 7533.04
# Foundation_CBlock 	 7581.94
# Neighborhood_Edwards 	 -7595.45
# Exterior1st_Plywood 	 7629.54
# HouseStyle_2.5Fin 	 -7682.88
# Neighborhood_StoneBr 	 -7684.71
# Exterior2nd_Stucco 	 7774.73
# Exterior1st_WdShing 	 -7833.73
# BsmtFinType2_BLQ 	 8062.39
# KitchenQual_Fa 	 -8070.35
# ExterQual_Fa 	 -8238.97
# Condition1_PosA 	 8280.4
# BsmtQual_Fa 	 -8655.15
# ExterQual_Gd 	 -8837.88
# Functional_Maj2 	 9205.26
# HouseStyle_1.5Unf 	 9435.77
# SaleType_ConLI 	 -9948.43
# BsmtExposure_No 	 -9992.01
# Foundation_Wood 	 10011.47
# BldgType_Duplex 	 -10276.91
# PavedDrive_Y 	 -10652.75
# Condition2_RRNn 	 10786.69
# Condition1_Feedr 	 10793.59
# Neighborhood_NridgHt 	 -10848.17
# SaleType_Oth 	 -10851.45
# Foundation_Slab 	 11238.26
# Exterior1st_AsbShng 	 -11381.84
# Neighborhood_BrkSide 	 -11469.73
# LotConfig_Corner 	 11483.18
# Functional_Min1 	 11658.01
# SaleType_ConLw 	 11713.17
# LotConfig_Inside 	 11836.12
# MasVnrType_unknown 	 11892.75
# BsmtFinType1_unknown 	 11935.77
# LandContour_HLS 	 -12137.77
# MSZoning_C (all) 	 12391.98
# LotConfig_FR2 	 -12461.34
# KitchenAbvGr 	 -12637.4
# Neighborhood_Mitchel 	 -12808.88
# HouseStyle_1.5Fin 	 13710.84
# RoofStyle_Gable 	 -13807.36
# Neighborhood_NPkVill 	 -14784.33
# BsmtExposure_Av 	 15040.07
# Neighborhood_CollgCr 	 15043.32
# LandContour_Lvl 	 15305.1
# Utilities_AllPub 	 -15305.1
# Street_Grvl 	 15868.24
# MSZoning_RM 	 -15868.24
# RoofMatl_WdShngl 	 15924.12
# Neighborhood_NAmes 	 16105.82
# Electrical_unknown 	 16347.81
# GarageQual_Fa 	 -16644.22
# Exterior2nd_Plywood 	 -16808.74
# RoofStyle_Flat 	 -16844.55
# RoofStyle_Gambrel 	 -16996.0
# SaleType_CWD 	 17111.76
# BsmtCond_Po 	 -17142.03
# BsmtFinType2_Unf 	 -17251.58
# Neighborhood_Crawfor 	 -17559.79
# GarageQual_Po 	 -18450.69
# Neighborhood_MeadowV 	 -18897.14
# GarageCond_Fa 	 19029.02
# Heating_Grav 	 -19218.44
# Functional_Typ 	 -19314.94
# LandSlope_Gtl 	 19340.62
# Exterior1st_BrkComm 	 19352.61
# Heating_OthW 	 19362.44
# GarageCond_Ex 	 20041.82
# BsmtQual_unknown 	 -20268.05
# Condition1_PosN 	 -20519.61
# BsmtCond_Fa 	 -20606.6
# Functional_Sev 	 20780.34
# Neighborhood_NoRidge 	 20914.22
# HouseStyle_1Story 	 -21411.46
# Exterior2nd_MetalSd 	 -21464.28
# Exterior2nd_HdBoard 	 21950.23
# SalePrice 	 -21958.62
# GarageCond_Po 	 22028.89
# Electrical_SBrkr 	 22662.07
# HouseStyle_SLvl 	 -22700.38
# GarageCond_Gd 	 23950.97
# Foundation_Stone 	 -24033.26
# GarageQual_Ex 	 -24443.24
# Condition2_RRAe 	 26046.11
# Neighborhood_NWAmes 	 29238.4
# LandSlope_Mod 	 -31176.74
# Exterior1st_HdBoard 	 -37000.5
# Condition2_Feedr 	 37507.1
# GarageQual_Gd 	 -38689.61
# Condition2_Artery 	 39995.01
# Neighborhood_Somerst 	 40675.47
# Electrical_FuseP 	 -41058.63
# Functional_Mod 	 -42757.23
# Condition1_RRNn 	 44097.06
# Condition2_RRAn 	 45505.25
# RoofMatl_Metal 	 46772.01
# RoofMatl_Tar&Grv 	 49880.69
# BsmtCond_Gd 	 50567.62
# RoofMatl_ClyTile 	 58413.13
# RoofMatl_Roll 	 63836.78
# RoofStyle_Mansard 	 74872.59
# Condition2_PosN 	 -83080.4
# Condition2_Norm 	 83342.89
# GarageQual_unknown 	 -87836.93
# GarageFinish_unknown 	 95441.53
# RoofMatl_WdShake 	 111029.7
# RoofMatl_Membran 	 124935.18
# RoofMatl_CompShg 	 153235.7
# Condition2_PosA 	 -193413.02
# RoofStyle_Shed 	 -608103.2

# %%
from sklearn import model_selection
model_selection.cross_val_score(lr,X =X, y=y, cv=5).mean()
# Out:
# 0.80948556050040776

# %% [markdown]
# К счастью в этот раз коэффициенты при признаках не улетели в космос, но всё равно достигли очень больших значений. Например `RoofStyle_Shed` получился в моем случае около `-514961`. А у некоторых признаков коэффициент уже равен 0, хотя не была применена регуляризация.

# %% [markdown]
# ## 1.6 Ridge и Lasso (4 балла)
#
# - Обучите Lasso и Ridge для разных значений регуляризации alpha
# - нарисуйте график значений коэффициентов модели для каждого признака, как мы делали на практике. По оси X будет значение alpha, по Y - значение коэффициента. на графике будет "радуга" из линий разных цветов(линий столько, сколько признаков).
# - Нарисуйте гистограмму, в которой по оси Y будет количество коэффициентов, равных 0 (<0.0001) для Loss регресиии, а по оси X - значение коэффициента альфа.
#
# alpha взять от 1 до 500 с каким-нибудь шагом. Но не переборщите, а то долго будете ждать.

# %%
from sklearn.linear_model import Lasso, Ridge

alphas = np.arange(1, 500, 10)
coefsLasso = np.zeros((alphas.shape[0], X.shape[1]))
coefsRidge = np.zeros((alphas.shape[0], X.shape[1]))
i = 0
for alpha in alphas:
    lasso = Lasso(alpha = alpha, random_state=42)
    lasso.fit(X, y)
    coefsLasso[i, :] = lasso.coef_    
    ridge = Ridge(alpha = alpha, random_state=42)
    ridge.fit(X, y)
    coefsRidge[i, :] = ridge.coef_
    i += 1

# %%
plt.figure(figsize=(10, 10))
for coef, feature in zip(coefs_lasso.T, df.columns):
    plt.plot(alphas, coef, label=feature, color=np.random.rand(3), linewidth=3)
plt.xlabel("alpha")
plt.ylabel("feature weight")
plt.title("Lasso")
# Out:
# Text(0.5,1,'Lasso')

# %%
plt.figure(figsize=(10, 10))
for coef, feature in zip(coefs_ridge.T, df.columns):
    plt.plot(alphas, coef, label=feature, color=np.random.rand(3), linewidth=3)
plt.xlabel("alpha")
plt.ylabel("feature weight")
plt.title("Ridge")
# Out:
# Text(0.5,1,'Ridge')

# %% [markdown]
# ## 1.7 Поиск оптимального alpha (6 баллов)
#
# - С помощью метода LassoCV найдите оптимальное значение alpha и напечатайте его, используя разбиение на 5 фолда в кроссвалидации (`cv=5`).
# - Нарисуйте график зависимости MSE от alpha (`mse_path_`).
# - Нарисуйте длинную гистограмму магнитуда признаков, как в классе, на которой будет показано значение коэффициента для каждого признака. Графк должен быть остортирован по величине коэффициентов. Признаки с нулевыми коэффициентами должны быть удалены.
# - Сколько в итоге ненулевых признаков осталось?
# - Выведите **среднее** ошибки предсказания на 5 фолдах (cv=5) для этой линейной регрессии с помощью функции [sklearn.model_selection.cross_val_score](http://scikit-learn.org/stable/modules/generated/sklearn.model_selection.cross_val_score.html). Укажите `scoring='neg_mean_squared_error'`, чтобы считалась [MSE](http://scikit-learn.org/stable/modules/model_evaluation.html#mean-squared-error). Качество должно быть лучше, чем у простой линейной регрессии.

# %% [markdown]
# ## 1.8 Предсказание на отложенной выборке (3 балла)
#
# - Используя [sklearn.model_selection.train_test_split](http://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html) разбейте датасет на 2 части - тренировочную и тестовую в соотношении 0.33. Не забудьте перемешать!
# - Напечатайте размерность X_train и X_test

# %% [markdown]
# Теперь, возьмите вашу самую мощную модель(не тренированную!). Запустите её тренировку по тренировочной выборке X_train, y_train с помощью функции `fit`. Постройте предсказания с помощью функции `predict`.

# %% [markdown]
# Визуализируйте scatter plot предсказанных значений и настоящих (`y_test`). У вас должен получиться график, точки которого расположены приблизительно вдоль некоторой прямой с разбросом. Идеальный предсказатель будет выглядить как набор точек вдоль прямой без разброса.

# %% [markdown]
# ## 1.9 Ограниченная версия ( 4 балла)
#
# Помните в самом начале мы оставили очень мало признаков по данным из heatmap. Настало время проверить как он себя покажет! К счастью они все сразу числовые, а не категориальные. Переиспользуйте тот дадасет, где вы уже поборолись с пропусками.
# Снова выделите отдельно X и y и запустите кроссвалидацию c 5 фолдами по Lasso с `alpha=1`.

# %% [markdown]
# Можете посмотреть еще много разных примеров обработки этого датасета тут: https://www.kaggle.com/c/house-prices-advanced-regression-techniques/kernels

# %% [markdown]
# А суть всего этого такова, что в итоге надо кучу времени потратить на подготовку признаков. Смотреть на кучу графиков а потом стакать модели.
